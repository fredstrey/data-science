# %% [markdown]
# <a href="https://colab.research.google.com/github/fredstrey/data-science/blob/main/analise_de_sentimento_chatgpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import openai

openai.api_key = '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'
maxtweets = 60
i = 0
listatweet = []

for tweet in sntwitter.TwitterSearchScraper('Felipe Neto since:2023-06-28 until:2023-06-29').get_items():
    if i >= maxtweets:
        break
    listatweet.append([tweet.date, tweet.url, tweet.username, tweet.content])
    i += 1

tweets_df = pd.DataFrame(listatweet, columns=['data', 'url', 'username', 'conteudo'])


sentiment_scores = []

for tweet in tweets_df['conteudo']:
    prompt = f"Analyze the sentiment of the following tweet about Felipe Neto:\n{tweet}\nand tell me if it is positive, negative, or neutral (return me only with negative, neutral and positive entrys)."
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.7
    )
    sentiment = response.choices[0].text.strip()
    sentiment_scores.append(sentiment)
positivo=0
negativo=0
print(sentiment_scores)
for score in sentiment_scores:
  if 'positive' in score:
    positivo+=1
  if 'negative' in score:
    negativo+=1
tweets_df
print("tweets positivos: " + str(positivo))
print("tweets negativos: " + str(negativo))
print("tweets neutros: " + str(abs(positivo+negativo-maxtweets)))
tweets_df
# Out:
# <ipython-input-10-6dff4f9867e8>:13: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   listatweet.append([tweet.date, tweet.url, tweet.username, tweet.content])
# <ipython-input-10-6dff4f9867e8>:13: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   listatweet.append([tweet.date, tweet.url, tweet.username, tweet.content])
# ['negative', 'positive', 'negative', 'Negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positivo', 'negative', 'negative', "I'm not sure what the sentiment of the tweet is.", 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative']
# tweets positivos: 13
# tweets negativos: 43
# tweets neutros: 4
#                         data  \
# 0  2023-06-28 23:59:59+00:00
# 1  2023-06-28 23:59:42+00:00
# 2  2023-06-28 23:59:41+00:00
# 3  2023-06-28 23:59:24+00:00
# 4  2023-06-28 23:59:21+00:00
# 5  2023-06-28 23:59:15+00:00
# 6  2023-06-28 23:59:14+00:00
# 7  2023-06-28 23:59:09+00:00
# 8  2023-06-28 23:59:09+00:00
# 9  2023-06-28 23:59:00+00:00
# 10 2023-06-28 23:58:41+00:00
# 11 2023-06-28 23:58:40+00:00
# 12 2023-06-28 23:57:55+00:00
# 13 2023-06-28 23:57:54+00:00
# 14 2023-06-28 23:57:53+00:00
# 15 2023-06-28 23:57:45+00:00
# 16 2023-06-28 23:57:38+00:00
# 17 2023-06-28 23:57:31+00:00
# 18 2023-06-28 23:57:29+00:00
# 8   @jannelindona @slinharees aaaa eu nao colo com...
# 9   @felipeneto Vc deveria tomar vergonha na cara ...
# 10  @slinharees @jannelindona Esse mano valak que ...
# 11  @rbeze30 @felipeneto Quer ensinar o Elon musk ...
# 12  @felipeneto Melhor que você tentando ensinar a...
# 13  @felipeneto Vc não nasceu,foi defecado 🤣🤣🤣🤣🤣🤣🤣...
# 14  @Chief117Br E trabalhava com o Felipe Neto? Se...
# 15  @felipeneto Rapaz, do jeito que ta indo faz se...
# 16  @felipeneto @felipeneto quem é você? É brasile...
# 17  Oi @felipeneto vc chegou a ver esse vídeo do r...
# 18  @felipeneto Felipe Neto, complete: quem senta ...
# 19  @Liliansnli @diegomuguetrj @felipeneto Caramba...
# 20                      @felipeneto Você falou lei né
# 21  @felipeneto Pois eu nasci vendo e ouvindo fala...
# 22    @popzinho_30 @i4fefo @felipeneto LGTVHDMILED4K+
# 23  @MBLivre Se o crime acontece dentro da platafo...
# 24                @felipeneto https://t.co/Osil4Pg21v
# 25  @jannelindona @slinharees De verdade agora ele...
# 26  @felipeneto Eu nasci pra ver um idiota como vo...
# 27  @felipeneto Vocês podem tudo! Chamar de tudo q...
# 28        @felipeneto Foca foca 🦭 sua hora vai chegar
# 29  @felipeneto Kkkkkk é  a vida Felipéti. \n\nEu ...
# 30  @felipeneto Não, só pode o imitador de foca \n...
# 31  @felipeneto Já ficou feio isso de você ficar p...
# 32  @felipeneto E eu pra ver um Youtuber querer re...
# 33  Bora ajudar essa senhora @_Janoninho @gleisi @...
# 34  @felipeneto E uma Foca querendo ensinar o que ...
# 35  gente, mas o que o Felipe Neto tem a ver com i...
# 36  @slpng_giants_pt 🏳️‍⚧️🖕🏻🖕🏻 quero a turma que a...
# 37                            @felipeneto E a blaze ?
# 38                              @felipeneto E verdade
# 39  @TheLanaBubble @QuimQueiroz3 @felipeneto Sim, ...
# 40  @diegomuguetrj @felipeneto E pq não falar? Des...
# 41  @slinharees @jannelindona Eu e o meu mano vala...
# 42  @EmanuelTSR @esquerdananet Esse argumento só s...
# 43                     @felipeneto @oliva20081 Talibã
# 44                 @Gustavo_Hermont @felipeneto Qual?
# 45  eu odeio o felipe neto mas tem varios tweets f...
# 46  @felipeneto Posso sentir nojo disso ainda?\n\n...
# 47           @felipeneto Opa qual sua formação mesmo?
# 48  @felipeneto Qual o problema? Vc se julgou comp...
# 49  @felipeneto Não existe recuperação para pessoa...
# 50          @felipeneto E o junento do FN criticando.
# 51  @felipeneto Vc é tão imbecil moço, que deveria...
# 52  @felipeneto Sou da época que quem ca ga va na ...
# 53  @felipeneto Vc não deveria nem ter nascido! Vc...
# 54              @felipeneto Deveria voltar a imitar 🦭
# 55  @felipeneto DEIXOU DE FAZER PROPAGANDA DA BLAZ...
# 56  @oldfelps @felipeneto Pfv Felipe tem criança d...
# 57  @felipeneto E quem vc acha que é para querer c...
# 58  @felipeneto Ué tem certeza que eles conhecem a...
# 59  @joaolmpm1 @felipeneto Moro é prova o que é se...

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.8
